# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time
s=Service("C:\\Users\\shoai\\.wdm\\drivers\\chromedriver\\win32\\99.0.4844.51\\chromedriver.exe")
driver=webdriver.Chrome(service=s)
driver.get('https://www.instagram.com/')
time.sleep(5)
driver.find_element(By.CLASS_NAME,'KPnG0').click()
time.sleep(3)
email_type=driver.find_element(By.ID,'email')
## Enter your facebook email
email_type.send_keys('SAMPLE USERNAME')
## Enter your email Password 
passw=driver.find_element(By.ID,'pass')
passw.send_keys('SAMPLE PASSWORD')
driver.find_element(By.ID,'loginbutton').click()
time.sleep(8)
driver.find_element(By.XPATH,"/html/body/div[5]/div/div/div/div[3]/button[2]").click()

# %% [markdown]
# ## Searching food and then finding the names of all tag containg food (ignoring #)

# %%
driver.find_element(By.XPATH,'//*[@id="react-root"]/section/nav/div[2]/div/div/div[2]/div[1]').click()
input_F=driver.find_element(By.XPATH,'//*[@id="react-root"]/section/nav/div[2]/div/div/div[2]/input')
input_F.send_keys('food')
time.sleep(1)
name=driver.find_elements(By.CLASS_NAME,'qyrsm')
name
for i in name:
    if 'food' in i.text and '#' not in i.text:
        print(i.text)
driver.find_element(By.XPATH,'//*[@id="react-root"]/section/nav/div[2]/div/div/div[2]/div[2]').click()
# Out:
# dilsefoodie
# foodtalkindia
# food_surfing.07
# foodandfitnessbyj
# hodophile_foodiepanda
# _food.sframe_
# food
# foodie_incarnate
# food.slayers_
# idontsharefoodsorry
# foodie._.hub
# food__junction
# food.babyy_
# khans_food_hub
# 2d_foodie_
# delhifoodwalks
# thedelhifood
# foodie.forever__
# delhi_street_food1
# food_bunny98
# delhifoodnest
# delhifoodguide
# food.quest.in
# dr.foodiehyd
# dying_for_food
# food.o.holic
# foodswerve
# foodie.ravi
# _cooknfoodie_
# foodemusafir
# foodiesafarii
# food_maple05
# food_wackadoos
# food__wonders
# next_food_in_menu
# food_flatters001
# foodiewe
# the.food.doodler
# tasty.foodrecipes
# cutefoodish
# food_lunatic
# yourfoodlab

# %%
driver.find_element(By.XPATH,'//*[@id="react-root"]/section/nav/div[2]/div/div/div[2]/div[1]').click()
input_F=driver.find_element(By.XPATH,'//*[@id="react-root"]/section/nav/div[2]/div/div/div[2]/input')
input_F.send_keys('So Delhi')
time.sleep(5)
a=driver.find_element(By.XPATH,'//*[@id="react-root"]/section/nav/div[2]/div/div/div[2]/div[3]/div/div[2]/div/div[1]/a')
a.click()

# %% [markdown]
# ### To follow the page or check wether its followed or not

# %%
from selenium.common.exceptions import NoSuchElementException
try:
    f=driver.find_element(By.XPATH,'//*[@id="react-root"]/section/main/div/header/section/div[1]/div[1]/div/div/div/span/span[1]/button/div')
    if(f.text=='Follow'):
        driver.find_element(By.CLASS_NAME,"_5f5mN").click()
    else:
        print("The page is alredy followed")
except NoSuchElementException:
    print("The page is alredy followed")
# Out:
# The page is alredy followed

# %% [markdown]
# ### To unfollow the page and check wether its unfollowed or not

# %%
from selenium.common.exceptions import NoSuchElementException
try:
    f=driver.find_element(By.XPATH,'//*[@id="react-root"]/section/main/div/header/section/div[1]/div[1]/div/div/div/span/span[1]/button/div')
    if(f.text!='Follow'):
        driver.find_element(By.CLASS_NAME,"_5f5mN").click()
#     driver.find_element(By.CLASS_NAME,"_5f5mN").click()
    driver.find_element(By.CLASS_NAME,"aOOlW").click()
except NoSuchElementException:
    print("The page is alredy Unfollowed")

# %% [markdown]
# ## To Like and Unlike the post from dilsefoodie

# %%
driver.find_element(By.XPATH,'//*[@id="react-root"]/section/nav/div[2]/div/div/div[2]/div[1]').click()
input_F=driver.find_element(By.XPATH,'//*[@id="react-root"]/section/nav/div[2]/div/div/div[2]/input')
input_F.send_keys('dilsefoodie')
time.sleep(5)
a=driver.find_element(By.XPATH,'//*[@id="react-root"]/section/nav/div[2]/div/div/div[2]/div[3]/div/div[2]/div/div[1]/a')
a.click()

# %% [markdown]
# ### To like the first 30 post of dilsefoodie handle

# %%
for i in range(30):
    like=driver.find_element(By.XPATH,'/html/body/div[6]/div[3]/div/article/div/div[2]/div/div/div[2]/section[1]/span[1]/button/div/span')
    li=like.get_attribute('innerHTML')
    if('Unlike') in li:
        print(i+1,"the post is alredy Liked")
    else:
        driver.find_element(By.XPATH,'/html/body/div[6]/div[3]/div/article/div/div[2]/div/div/div[2]/section[1]/span[1]/button').click()
    if(i==0):
        driver.find_element(By.XPATH,'/html/body/div[6]/div[2]/div/div/button').click()
    else:
        driver.find_element(By.XPATH,'/html/body/div[6]/div[2]/div/div[2]/button/div/span').click()
    time.sleep(2)

# %% [markdown]
# ### Now for clearity unliked 8-9 post to see is our answer coming correct or not

# %% [markdown]
# ### To unlike the first 30 post of the handle dilsefood and also check if its alredy unliked or not

# %%
for i in range(30):
    a=driver.find_element(By.XPATH,'/html/body/div[6]/div[3]/div/article/div/div[2]/div/div/div[2]/section[1]/span[1]/button/div/span')
    un=a.get_attribute('innerHTML')
    if("Like") in un:
        print(i+1,'the post is alredy Un-Liked')
    else:
        a.click()
    if(i==0):
        driver.find_element(By.XPATH,'/html/body/div[6]/div[2]/div/div/button').click()
    else:
        driver.find_element(By.XPATH,'/html/body/div[6]/div[2]/div/div[2]/button/div/span').click()
    time.sleep(3)

# %%
driver.find_element(By.XPATH,'/html/body/div[6]/div[1]/button').click()

# %% [markdown]
# ## Extracting the list of Followers

# %% [markdown]
# ### Extracting the list of followers of username foodtalkindia

# %%
driver.find_element(By.XPATH,'//*[@id="react-root"]/section/nav/div[2]/div/div/div[2]/div[1]').click()
input_F=driver.find_element(By.XPATH,'//*[@id="react-root"]/section/nav/div[2]/div/div/div[2]/input')
input_F.send_keys('foodtalkindia')
time.sleep(5)
a=driver.find_element(By.XPATH,'//*[@id="react-root"]/section/nav/div[2]/div/div/div[2]/div[3]/div/div[2]/div/div[1]/a')
a.click()

# %%
driver.find_element(By.XPATH,'//*[@id="react-root"]/section/main/div/header/section/ul/li[2]/a/div').click()

# %%
l=1
for j in range(30):
    if(l>500):
        break
    lis=driver.find_elements(By.CLASS_NAME,'MqpiF')
    for i in lis:
        print(l,i.text)
        l+=1
        if(l>500):
            break
    driver.execute_script('window.scrollBy(0,1000);')
    time.sleep(3)
# Out:
# 1 lavish3
# 2 bhatiaboii
# 3 inidhiarora25
# 4 im_juliana1
# 5 a_dailydesire
# 6 achal_bhangale_407
# 7 akshay_jith_______
# 8 deva.eth
# 9 czlife_for_you
# 10 0zayn8
# 11 urv.jpg
# 12 jitenderj2
# 13 parth.arora24
# 14 flavoursofindiabykaran
# 15 abbasicreations
# 16 sujata_athani
# 17 kothari.twinkle2020
# 18 somani.kani
# 19 the_ishaan_editor_
# 20 ankiita419
# 21 varunboy514
# 22 midhunabhinav_
# 23 lakkufoodfactory
# 24 imrohitkarnwal
# 25 lavish3
# 26 bhatiaboii
# 27 inidhiarora25
# 28 im_juliana1
# 29 a_dailydesire
# 30 achal_bhangale_407
# 31 akshay_jith_______
# 32 deva.eth
# 33 czlife_for_you
# 34 0zayn8
# 35 urv.jpg
# 36 jitenderj2
# 37 parth.arora24
# 38 flavoursofindiabykaran
# 39 abbasicreations
# 40 sujata_athani
# 41 kothari.twinkle2020
# 42 somani.kani
# 43 the_ishaan_editor_
# 44 ankiita419
# 45 varunboy514
# 46 midhunabhinav_
# 47 lakkufoodfactory
# 48 imrohitkarnwal
# 49 lavish3
# 50 bhatiaboii
# 51 inidhiarora25
# 52 im_juliana1
# 53 a_dailydesire
# ...

# %% [markdown]
# ### Print all the followers of “foodtalkindia” that you are following but those who don’t follow you

# %%
foll=driver.find_elements(By.CLASS_NAME,'T0kll')
for i in range(0,len(foll),2):
    if(foll[i].text =="Following"):
        print(foll[i-1].text)
# Out:
# im_juliana1
# achal_bhangale_407
# akshay_jith_______
# deva.eth

# %%
driver.find_element(By.XPATH,'/html/body/div[6]/div/div/div/div[1]/div/div[3]/div/button').click()
## This has been done to close the followers tab by clicking cross

# %% [markdown]
# ## Check the story of ‘coding.ninjas’. Consider the following Scenarios and print error messages accordingly -
# ## 1.If You have already seen the story.
# ## 2.Or The user has no story.
# ## 3.Or View the story if not yet seen.

# %%
driver.find_element(By.XPATH,'//*[@id="react-root"]/section/nav/div[2]/div/div/div[2]/div[1]').click()
input_F=driver.find_element(By.XPATH,'//*[@id="react-root"]/section/nav/div[2]/div/div/div[2]/input')
input_F.send_keys('coding.ninjas')
time.sleep(5)
a=driver.find_element(By.XPATH,'//*[@id="react-root"]/section/nav/div[2]/div/div/div[2]/div[3]/div/div[2]/div/div[1]/a')
a.click()

# %%
from selenium.common.exceptions import NoSuchElementException
while True:
    try:
        v=driver.find_element(By.XPATH,'//*[@id="react-root"]/section/main/div/header/div/div/canvas')
        if v.get_attribute('height') == '208':
            print('All The story is seen')
            break
        else:
            driver.find_element(By.XPATH,'//*[@id="react-root"]/section/main/div/header/div/div').click()
            time.sleep(5)
            driver.find_element(By.XPATH,'//*[@id="react-root"]/section/div[3]/button').click()
    except NoSuchElementException:
        print('there is no story today')
        break
# Out:
# All The story is seen
